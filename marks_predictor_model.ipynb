# %%
import pandas as pd
df = pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid')

# %%
# check missing values
df.isna().sum().sum()
# Out:
# 91

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
# check duplicates value
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include='object').columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_col = ["gender", "part_time_job", "diet_quality", "parental_education_level", "internet_quality", "extracurricular_participation"]

# %%
for col in categorical_col:
    print(col)
    print(df[col].value_counts())
    print()
# Out:
# gender
# gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
#
# part_time_job
# part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
#
# diet_quality
# diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
#
# parental_education_level
# parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
#
# internet_quality
# internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
#
# extracurricular_participation
# extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
for col in categorical_col:
  sns.countplot(data=df, x=col)
  plt.title("Distribution of {col}")
  plt.xticks(rotation=45)
  plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
  sns.scatterplot(data=df, x=feature, y="exam_score")
  plt.title(f"{feature} vs Exam Score")
  plt.show()

# %%
for col in categorical_col:
  sns.boxplot(data=df, x=col, y="exam_score")
  plt.title(f"Exam score by {col}")
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# starting with model building

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day", "attendance_percentage", "mental_health_rating", "sleep_hours", "part_time_job"]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %%
le = LabelEncoder()

# %%
df_model['part_time_job'] = le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression" : {
        "model" : LinearRegression(),
        "params" : {}
    },
    "DecisionTree" : {
        "model" : DecisionTreeRegressor(),
        "params" : {
            "max_depth" : [3,5,10],
            "min_samples_split" : [2,5]
        }
    },
    "RandomForest" : {
        "model" : RandomForestRegressor(),
        "params" : {
            "n_estimators" : [50,100],
            "max_depth" : [5,10],
            "min_samples_split" : [2,5]
    }
}
}

# %%
best_models = []

# %%
for name,config in models.items():
  print(f"Training {name}")
  grid_search = GridSearchCV(config['model'], config['params'], cv=5, scoring='neg_mean_squared_error')
  grid_search.fit(X_train, y_train)

  y_predict = grid_search.predict(X_test)
  rmse = np.sqrt(mean_squared_error(y_test, y_predict))
  print(f"RMSE: {rmse}")
  r2 = r2_score(y_test, y_predict)
  print(f"R2 Score: {r2}")
  best_models.append({
      "name" : name,
      "best_params" : grid_search.best_params_,
      "rmse" : rmse,
      "r2" : r2
  })
# Out:
# Training LinearRegression
# RMSE: 6.709387069063747
# R2 Score: 0.8208263867941454
# Training DecisionTree
# RMSE: 8.351616376788256
# R2 Score: 0.7223808427549878
# Training RandomForest
# RMSE: 7.630964058653501
# R2 Score: 0.7682246886334951

# %%
best_models
# Out:
# [{'name': 'LinearRegression',
#   'best_params': {},
#   'rmse': 6.709387069063747,
#   'r2': 0.8208263867941454},
#  {'name': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': 8.351616376788256,
#   'r2': 0.7223808427549878},
#  {'name': 'RandomForest',
#   'best_params': {'max_depth': 10,
#    'min_samples_split': 5,
#    'n_estimators': 100},
#   'rmse': 7.630964058653501,
#   'r2': 0.7682246886334951}]

# %%
result_df = pd.DataFrame(best_models)

# %%
result_df.sort_values(by='rmse')
# Out:
#                name                                        best_params  \
# 0  LinearRegression                                                 {}
# 2      RandomForest  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 1      DecisionTree           {'max_depth': 5, 'min_samples_split': 2}
#
#        rmse        r2
# 0  6.709387  0.820826
# 2  7.630964  0.768225
# 1  8.351616  0.722381

# %%
import joblib

# %%
best_row = result_df.sort_values(by='rmse').iloc[0]

# %%
best_row
# Out:
# name           LinearRegression
# best_params                  {}
# rmse                   6.709387
# r2                     0.820826
# Name: 0, dtype: object

# %%
best_model_name = best_row['name']
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
final_model = best_model_config['model']

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 52.00021266,  93.9348698 ,  85.98146352,  52.76981731,
#         45.77718556,  54.1048007 ,  73.1673932 ,  73.06952749,
#         70.21478147,  64.22442454,  84.62669148,  82.34026337,
#         49.82715484,  57.8301418 ,  73.17116424,  94.97908174,
#         70.40477667,  76.9384696 ,  42.46689961,  56.00371918,
#         70.64707086,  74.93620762,  66.16326409,  77.28506823,
#         56.84795774,  78.70974568,  71.57182983,  54.97205488,
#         87.18702105, 101.05772654,  95.41329797,  71.17203049,
#         81.39667248,  68.48671733,  70.61133466,  63.2526023 ,
#         62.67344973,  54.8320808 ,  62.03082708,  94.31676369,
#         74.18329974,  64.74589097,  90.09302039,  55.22074637,
#         86.41513985,  71.53075848,  53.80314099,  74.30096446,
#         85.58995874,  54.52840609,  51.45722985,  61.04952323,
#         64.7719743 ,  51.04420646,  60.9230965 ,  68.31359587,
#         64.87101299,  70.58020241,  71.09065397,  59.16887727,
#         37.08526345,  55.78485738,  63.64137371,  89.38708519,
#         52.60961208,  83.16135013,  83.02517528,  71.53255701,
#         57.67033365,  88.43006865,  81.50258474, 105.61559246,
#         72.96464702,  79.36878895,  85.2652158 ,  53.35891573,
#         70.20854282,  98.05726756,  67.54393569,  63.8141856 ,
#         57.45957817,  79.59311223,  63.02878767,  72.88151862,
#         75.61018805,  90.63779187,  80.07009373,  76.52318174,
#         82.07659987,  66.59608214,  68.37208385,  66.18579405,
#         59.04507085,  72.24230521,  64.69940863,  67.31865096,
#         61.28183191,  62.66539553,  67.28188611,  48.92767151,
#         77.45864808,  85.07548216,  86.19114402,  74.66430702,
#         70.06256803,  74.59529628,  54.20184513,  53.62059091,
#         82.2417553 ,  87.06455834,  65.24574029, 100.68914231,
#         86.33867011,  69.29688277,  45.70477712,  58.14930281,
#         57.63384029,  87.47666446,  91.91388896,  74.91557123,
#         79.94294863,  81.17073179,  68.04815179,  80.46322951,
#         76.45016176,  90.35284716,  81.52560059,  74.47177811,
#         78.70663792,  26.72264534,  74.26344109,  65.38478204,
#         65.33003352,  66.55221819,  80.07572706,  41.0826638 ,
#         55.57788334,  74.83885426,  77.67278715,  47.21912588,
#         83.69220041,  82.16654734,  89.8219083 ,  92.44727813,
#         61.60372745,  56.7801663 ,  94.48143692,  82.19382145,
#         57.55284809,  63.24170396,  86.38678834,  58.44760136,
#         92.78532362,  53.89238682,  48.56143345, 100.79359858,
#         70.1122084 ,  65.81297953,  51.22222835,  72.00500419,
#         78.79038574,  68.67625259,  57.13538481,  84.3068876 ,
#         76.36598796,  66.0866954 ,  81.1148883 ,  70.71345219,
#         69.19275373,  91.69729711,  74.8589124 ,  49.85660749,
#         69.95368226,  83.87763264,  77.09472949,  82.25691263,
#         68.22890505, 104.70803339,  66.54423847,  54.12381522,
#        102.67076152,  69.31005922])

# %%
# Out:
# ['best_model.pkl']
